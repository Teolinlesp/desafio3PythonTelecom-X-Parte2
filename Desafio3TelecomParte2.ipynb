# %% [markdown]
# <a href="https://colab.research.google.com/github/Teolinlesp/desafio3PythonTelecom-X-Parte2/blob/main/Desafio3TelecomParte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛠️ Preparación de los Datos

# %% [markdown]
# ## Extracción del Archivo Tratado Parte 1

# %%
import pandas as pd
datosTelecom2 = pd.read_csv("datos_tratados.csv")
datosTelecom2.head()
# Out:
#    ID_Cliente  Abandono  Género  Adulto_Mayor  Pareja  Dependientes  \
# 0  0002-orfbo       0.0  female             0       1             1
# 1  0003-mknfe       0.0    male             0       0             0
# 2  0004-tlhlj       1.0    male             0       0             0
# 3  0011-igkff       1.0    male             1       1             0
# 4  0013-exchz       1.0  female             1       1             0
#
#    Antigüedad_Meses  Teléfono_Servicio  Teléfono_Múltiples_Líneas  \
# 0                 9                  1                        0.0
# 1                 9                  1                        1.0
# 2                 4                  1                        0.0
# 3                13                  1                        0.0
# 4                 3                  1                        0.0
#
#   Internet_Tipo_Servicio  ... Internet_Protección_Dispositivo  \
# 0                    dsl  ...                             0.0
# 1                    dsl  ...                             0.0
# 2            fiber optic  ...                             1.0
# 3            fiber optic  ...                             1.0
# 4            fiber optic  ...                             0.0
#
#   Internet_Soporte_Técnico  Internet_TV_Streaming  \
# 0                      1.0                    1.0
# 1                      0.0                    0.0
# 2                      0.0                    0.0
# 3                      0.0                    1.0
# 4                      1.0                    1.0
#
#    Internet_Películas_Streaming  Cuenta_Tipo_Contrato  \
# 0                           0.0              one year
# 1                           1.0        month-to-month
# 2                           0.0        month-to-month
# 3                           1.0        month-to-month
# 4                           0.0        month-to-month
#
#    Cuenta_Facturación_Sin_Papel Cuenta_Método_Pago  Cuenta_Cargo_Mensual  \
# 0                             1       mailed check                  65.6
# 1                             0       mailed check                  59.9
# 2                             1   electronic check                  73.9
# 3                             1   electronic check                  98.0
# 4                             1       mailed check                  83.9
#
#   Cuenta_Cargo_Total  Cuentas_Diarias
# 0             593.30         2.186667
# 1             542.40         1.996667
# 2             280.85         2.463333
# 3            1237.85         3.266667
# 4             267.40         2.796667
#
# [5 rows x 22 columns]

# %%
columnas_binarias = [
    'Abandono',
    'Teléfono_Múltiples_Líneas',
    'Internet_Protección_Dispositivo',
    'Internet_Soporte_Técnico',
    'Internet_Películas_Streaming'
]

for col in columnas_binarias:
    datosTelecom2[col] = datosTelecom2[col].astype('Int64')
datosTelecom2.head()
# Out:
#    ID_Cliente  Abandono  Género  Adulto_Mayor  Pareja  Dependientes  \
# 0  0002-orfbo         0  female             0       1             1
# 1  0003-mknfe         0    male             0       0             0
# 2  0004-tlhlj         1    male             0       0             0
# 3  0011-igkff         1    male             1       1             0
# 4  0013-exchz         1  female             1       1             0
#
#    Antigüedad_Meses  Teléfono_Servicio  Teléfono_Múltiples_Líneas  \
# 0                 9                  1                          0
# 1                 9                  1                          1
# 2                 4                  1                          0
# 3                13                  1                          0
# 4                 3                  1                          0
#
#   Internet_Tipo_Servicio  ... Internet_Protección_Dispositivo  \
# 0                    dsl  ...                               0
# 1                    dsl  ...                               0
# 2            fiber optic  ...                               1
# 3            fiber optic  ...                               1
# 4            fiber optic  ...                               0
#
#   Internet_Soporte_Técnico  Internet_TV_Streaming  \
# 0                        1                    1.0
# 1                        0                    0.0
# 2                        0                    0.0
# 3                        0                    1.0
# 4                        1                    1.0
#
#    Internet_Películas_Streaming  Cuenta_Tipo_Contrato  \
# 0                             0              one year
# 1                             1        month-to-month
# 2                             0        month-to-month
# 3                             1        month-to-month
# 4                             0        month-to-month
#
#    Cuenta_Facturación_Sin_Papel Cuenta_Método_Pago  Cuenta_Cargo_Mensual  \
# 0                             1       mailed check                  65.6
# 1                             0       mailed check                  59.9
# 2                             1   electronic check                  73.9
# 3                             1   electronic check                  98.0
# 4                             1       mailed check                  83.9
#
#   Cuenta_Cargo_Total  Cuentas_Diarias
# 0             593.30         2.186667
# 1             542.40         1.996667
# 2             280.85         2.463333
# 3            1237.85         3.266667
# 4             267.40         2.796667
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Eliminar Columnas no relevantes

# %%
datosTelecom2 = datosTelecom2.drop(columns=["ID_Cliente"], errors="ignore")
datosTelecom2.head()
# Out:
#    Abandono  Género  Adulto_Mayor  Pareja  Dependientes  Antigüedad_Meses  \
# 0         0  female             0       1             1                 9
# 1         0    male             0       0             0                 9
# 2         1    male             0       0             0                 4
# 3         1    male             1       1             0                13
# 4         1  female             1       1             0                 3
#
#    Teléfono_Servicio  Teléfono_Múltiples_Líneas Internet_Tipo_Servicio  \
# 0                  1                          0                    dsl
# 1                  1                          1                    dsl
# 2                  1                          0            fiber optic
# 3                  1                          0            fiber optic
# 4                  1                          0            fiber optic
#
#   Internet_Seguridad_En_Línea  ... Internet_Protección_Dispositivo  \
# 0                          no  ...                               0
# 1                          no  ...                               0
# 2                          no  ...                               1
# 3                          no  ...                               1
# 4                          no  ...                               0
#
#    Internet_Soporte_Técnico  Internet_TV_Streaming  \
# 0                         1                    1.0
# 1                         0                    0.0
# 2                         0                    0.0
# 3                         0                    1.0
# 4                         1                    1.0
#
#    Internet_Películas_Streaming  Cuenta_Tipo_Contrato  \
# 0                             0              one year
# 1                             1        month-to-month
# 2                             0        month-to-month
# 3                             1        month-to-month
# 4                             0        month-to-month
#
#   Cuenta_Facturación_Sin_Papel  Cuenta_Método_Pago Cuenta_Cargo_Mensual  \
# 0                            1        mailed check                 65.6
# 1                            0        mailed check                 59.9
# 2                            1    electronic check                 73.9
# 3                            1    electronic check                 98.0
# 4                            1        mailed check                 83.9
#
#    Cuenta_Cargo_Total  Cuentas_Diarias
# 0              593.30         2.186667
# 1              542.40         1.996667
# 2              280.85         2.463333
# 3             1237.85         3.266667
# 4              267.40         2.796667
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Separar variable objetivo (Churn)

# %%
datosTelecom2["Abandono"].value_counts()
# Out:
# Abandono
# 0    5174
# 1    1869
# Name: count, dtype: Int64

# %%
X = datosTelecom2.drop("Abandono", axis=1)
y = datosTelecom2["Abandono"]

# %%
y.isnull().sum()
# Out:
# np.int64(224)

# %% [markdown]
# ## Encoding
# Convertimos variables categóricas en numéricas.

# %%
X = pd.get_dummies(X, drop_first=True)

# %% [markdown]
# ### Verificación de la Proporción de Cancelación (Churn)

# %%
proporcion = y.value_counts(normalize=True)
print(proporcion)
# Out:
# Abandono
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: Float64

# %%
# En porcentaje para ver desvalance
print(y.value_counts(normalize=True) * 100)
# Out:
# Abandono
# 0    73.463013
# 1    26.536987
# Name: proportion, dtype: Float64

# %% [markdown]
# ## Balanceo de Clases

# %%
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py:399: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1559/1919146984.py in <cell line: 0>()
#       2
#       3 smote = SMOTE(random_state=42)
# ----> 4 X_res, y_res = smote.fit_resample(X_scaled, y)
#
# /usr/local/lib/python3.12/dist-packages/imblearn/base.py in fit_resample(self, X, y, **params)
#     202             The corresponding label of `X_resampled`.
#     203         """
# --> 204         return super().fit_resample(X, y, **params)
#     205
#     206     def _more_tags(self):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/imblearn/base.py in fit_resample(self, X, y, **params)
#      97             The corresponding label of `X_resampled`.
#      98         """
# ---> 99         check_classification_targets(y)
#     100         arrays_transformer = ArraysTransformer(X, y)
#     101         X, y, binarize_y = self._check_X_y(X, y)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     212         Target values.
#     213     """
# --> 214     y_type = type_of_target(y, input_name="y")
#     215     if y_type not in [
#     216         "binary",
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in type_of_target(y, input_name, raise_unknown)
#     415         data = y.data if issparse(y) else y
#     416         if xp.any(data != xp.astype(data, int)):
# --> 417             _assert_all_finite(data, input_name=input_name)
#     418             return "continuous" + suffix
#     419
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input y contains NaN.

# %% [markdown]
# ## Normalización o Estandarización (si es necesario)
# Evalúa la necesidad de normalizar o estandarizar los datos, según los modelos que se aplicarán. Modelos basados en distancia, como KNN, SVM, Regresión Logística y Redes Neuronales, requieren este preprocesamiento. Por otro lado, modelos basados en árboles, como Decision Tree, Random Forest y XGBoost, no son sensibles a la escala de los datos.

# %%
from sklearn.preprocessing import StandardScaler

escalar = StandardScaler()

X_escaledo = escalar.fit_transform(X)
